# %%
import matplotlib.pyplot as plt

from agfalta.leem.base import LEEMStack
from agfalta.leem import driftnorm

# %%
#stack = LEEMStack.load("cache/test_stack_normed_aligned1.lstk")
stack = LEEMStack("media/test_stack_IV_g-Cu")

# %%
#driftnorm.normalize_stack(stack, "channelplate.dat", dark_counts=110)

alignment = driftnorm.align_stack(stack, algorithm="ecc", mask_outer=0.4, trafo="translation")
stack.save("media/test_stack_normed_aligned.lstk")

plt.plot([m[0, 2] for m in stack.alignment])
plt.plot([m[1, 2] for m in stack.alignment])
# Out:
# ▕▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▏ 100.0 % Calculating drift (ECC)... (0:00:35)

# %%
import agfalta.leem.plotting as lp

# %%
lp.plot_movie(stack[::30])
